# %% [markdown]
# <table align="left">
#   <td>
#     <a target="_blank" href=""><img src="https://www.tensorflow.org/images/colab_logo_32px.png" />Run in Google Colab</a>
#   </td>
# </table>

# %% [markdown]
# ***COVID 19:***
#
# **Curvas de crecimiento del número de casos y del número de muertes.**
#
# **Tasa de mortalidad respecto al número de infectados.**
#
# Los datos usados para las gráficas están sincronizados y son descargados del Portal de datos abiertos de la Unión Europea [ver página](https://data.europa.eu/euodp/es/data/dataset/covid-19-coronavirus-data/resource/260bbbde-2316-40eb-aec3-7cd7bfc2f590)
#
# En las curvas de crecimiento los países se han agrupado por valores cercanos respecto al número de casos. Tenga en cuenta las escalas en cada uno de los gráficos.
#
# Para ver las gráficas pulse en "[ ]" que se muestra en la siguiente línea. Si la ejecución se queda en el mensaje "por ejemplo 0" pulse en "stop" y vuelva a darle al "play".

# %%
# !git clone -l -s https://github.com/dalatorrem/covid cloned-repo # github Darío Latorre
# %cd cloned-repo
# !ls1
from funciones_covid import *
visualizar()
# Out:
# Cloning into 'cloned-repo'...
# ...
# remote: Enumerating objects: 122, done.
# remote: Total 122 (delta 0), reused 0 (delta 0), pack-reused 122
# Receiving objects: 100% (122/122), 30.47 KiB | 1.32 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /content/cloned-repo
# /bin/bash: ls1: command not found
# Introduzca días para los
# gráficos de curvas.
# El día 0 corresponde al:
# 31 de diciembre de 2019
# Introduzca el día inicial,
# por ejemplo 0
# 0
# Introduzca el último día,
# valor máximo 261
# 260
# ###############################################################################################################################################################################################################################################################
# ...
